# %% [markdown]
# ## Super sales Forecasting and Exploratory Data Analysis

# %%
import os, types
from botocore.client import Config
import ibm_boto3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import matplotlib.ticker as ticker

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='bE7fXuYI_W-m7TAbmuSNMcsLfUgRy7ioOmN4EsN50-7d',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'sabheen-donotdelete-pr-xso2qwcdnicsfi'
object_key = '_f6b72cc08250e1fff8b5aefce029256c_Sales-Superstore-Dataset.xlsx'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']

# Reading Excel file through IBM WATSON STUDIO
# In normal way we use df=pd.read_excel("filename.xlsx")
df= pd.read_excel(body.read())

# reading first 10 rows
df.head(10)
# Out:
#           Category          City        Country     Customer Name  \
# 0  Office Supplies       Houston  United States     Darren Powers
# 1  Office Supplies    Naperville  United States     Phillina Ober
# 2  Office Supplies    Naperville  United States     Phillina Ober
# 3  Office Supplies    Naperville  United States     Phillina Ober
# 4  Office Supplies  Philadelphia  United States        Mick Brown
# 5  Office Supplies        Athens  United States     Jack O'Briant
# 6  Office Supplies   Los Angeles  United States  Lycoris Saunders
# 7        Furniture     Henderson  United States     Maria Etezadi
# 8  Office Supplies     Henderson  United States     Maria Etezadi
# 9  Office Supplies     Henderson  United States     Maria Etezadi
#
#    Manufacturer Order Date        Order ID  Postal Code  \
# 0  Message Book 2011-01-04  CA-2011-103800        77095
# 1           GBC 2011-01-05  CA-2011-112326        60540
# 2         Avery 2011-01-05  CA-2011-112326        60540
# 3         SAFCO 2011-01-05  CA-2011-112326        60540
# 4         Avery 2011-01-06  CA-2011-141817        19143
# 5         Dixon 2011-01-07  CA-2011-106054        30605
# 6         Xerox 2011-01-07  CA-2011-130813        90049
# 7        Global 2011-01-07  CA-2011-167199        42420
# 8        Rogers 2011-01-07  CA-2011-167199        42420
# 9         Ibico 2011-01-07  CA-2011-167199        42420
#
#                                         Product Name   Region  ...  Ship Date  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central  ... 2011-01-08
# 1         GBC Standard Plastic Binding Systems Combs  Central  ... 2011-01-09
# 2                                          Avery 508  Central  ... 2011-01-09
# 3                      SAFCO Boltless Steel Shelving  Central  ... 2011-01-09
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...     East  ... 2011-01-13
# 5  Dixon Prang Watercolor Pencils, 10-Color Set w...    South  ... 2011-01-08
# 6                                          Xerox 225     West  ... 2011-01-09
# 7            Global Deluxe High-Back Manager's Chair    South  ... 2011-01-11
# 8            Rogers Handheld Barrel Pencil Sharpener    South  ... 2011-01-11
# 9                Ibico Hi-Tech Manual Binding System    South  ... 2011-01-11
#
#         Ship Mode         State Sub-Category Discount  Number of Records  \
# 0  Standard Class         Texas        Paper      0.2                  1
# 1  Standard Class      Illinois      Binders      0.8                  1
# 2  Standard Class      Illinois       Labels      0.2                  1
# 3  Standard Class      Illinois      Storage      0.2                  1
# 4  Standard Class  Pennsylvania          Art      0.2                  1
# 5     First Class       Georgia          Art      0.0                  1
# 6    Second Class    California        Paper      0.0                  1
# 7  Standard Class      Kentucky       Chairs      0.0                  1
# 8  Standard Class      Kentucky          Art      0.0                  1
# 9  Standard Class      Kentucky      Binders      0.0                  1
#
#    Profit  Profit Ratio  Quantity  Sales
# 0       6          0.34         2     16
# 1      -5         -1.55         2      4
# 2       4          0.36         3     12
# 3     -65         -0.24         3    273
# 4       5          0.25         3     20
# 5       5          0.41         3     13
# 6       9          0.48         3     19
# 7     746          0.29         9   2574
# 8       1          0.27         2      5
# 9     274          0.45         2    610
#
# [10 rows x 21 columns]

# %%
df.describe() # describing data in terms of statistics
# Out:
#         Postal Code     Discount  Number of Records       Profit  \
# count   9994.000000  9994.000000             9994.0  9994.000000
# mean   55190.379428     0.156203                1.0    28.651891
# std    32063.693350     0.206452                0.0   234.255712
# min     1040.000000     0.000000                1.0 -6600.000000
# 25%    23223.000000     0.000000                1.0     2.000000
# 50%    56430.500000     0.200000                1.0     9.000000
# 75%    90008.000000     0.200000                1.0    29.000000
# max    99301.000000     0.800000                1.0  8400.000000
#
#        Profit Ratio     Quantity         Sales
# count   9994.000000  9994.000000   9994.000000
# mean       0.120532     3.789574    229.873324
# std        0.466923     2.225110    623.248946
# min       -2.750000     1.000000      0.000000
# 25%        0.070000     2.000000     17.000000
# 50%        0.270000     3.000000     54.500000
# 75%        0.360000     5.000000    210.000000
# max        0.500000    14.000000  22638.000000
